# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os
    
load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[  
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"},
    ]
)

print(response.choices[0].message.content)
# Out:
# whistle cinder lantern marble echo quartz velvet tundra saffron nebula

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=408, prompt_tokens=24, total_tokens=432, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=384, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[  
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"},
    ],
    reasoning_effort="minimal"
)

print(response.choices[0].message.content)
# Out:
# Here are 10 random words:
#
# 1) lantern
# 2) brisk
# 3) meadow
# 4) prism
# 5) echo
# 6) velvet
# 7) canyon
# 8) quill
# 9) marigold
# 10) ripple

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=58, prompt_tokens=24, total_tokens=82, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %% [markdown]
# ### Google Genai Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        "you are a helpful assistant", "can you print 15 reandom words?"
    ]
)

print(response.text)
# Out:
# Here are 15 random words for you:
#
# 1.  **Mountain**
# 2.  **Smile**
# 3.  **Laptop**
# 4.  **Ocean**
# 5.  **Journey**
# 6.  **Whisper**
# 7.  **Guitar**
# 8.  **Sunshine**
# 9.  **Library**
# 10. **Curtain**
# 11. **Shadow**
# 12. **Biscuit**
# 13. **Rocket**
# 14. **Dragon**
# 15. **Feather**

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq

client = Groq(api_key=os.getenv("GROQ_API_KEY"))

chat_completion = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 20 random words?"},
    ],
    model="llama-3.3-70b-versatile"
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Space
# 2. Helicopter
# 3. Caramel
# 4. Banana
# 5. Guitar
# 6. Snowflake
# 7. Perfume
# 8. Llama
# 9. Coffee
# 10. Bicycle
# 11. Bubble
# 12. Starfish
# 13. Pineapple
# 14. Kitten
# 15. Harmonica
# 16. Football
# 17. Peacock
# 18. Typewriter
# 19. Glitter
# 20. Compass
